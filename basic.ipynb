# %% [markdown]
#  String

# %%
s = "Vaibhav"
print(s)
# Out:
# Vaibhav

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'V'

# %%
s[5]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 'v'

# %%
s[-2]
# Out:
# 'a'

# %%
s[0:2]
# Out:
# 'Va'

# %%
s[:-1]
# Out:
# 'Vaibha'

# %%
s[-4:]
# Out:
# 'bhav'

# %%
v = "vaibhav"

# %%
print(v[::-1])
# Out:
# vahbiav

# %%
b =[1,2,3,4,5]
print(b[::-1])
# Out:
# [5, 4, 3, 2, 1]

# %%
a = "this is my vary first programming class's"
print(a)
# Out:
# this is my vary first programming class's

# %%
a = 'this is my vary first programming class"s'
print(a)
# Out:
# this is my vary first programming class"s

# %%
a[8]
# Out:
# 'm'

# %%
a[1:6]
# Out:
# 'his i'
